# %%
def calc(num1,num2):
    ty = ""
    try: 
        print(num1/num2)
    except ZeroDivisionError:
        print("Hey you are trying to divide the number with 0")
    except TypeError:
        ty = "Hey give a valuable number not characters"
    finally:
        print("Finally prints")
    
    if ty:
        return 10+20
        
    

calc(10,"num")
# Out:
# 30
