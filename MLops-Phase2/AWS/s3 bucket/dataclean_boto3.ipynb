# %% [markdown]
# Imports & boto3 Client

# %%
import boto3
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %% [markdown]
# Initialize S3 client (uses your AWS CLI credentials):

# %%
s3 = boto3.client("s3")

# %% [markdown]
# 2. Download Raw Dataset from S3

# %%
bucket_name = "aws-practice-visualpath"
key = "housing/house_new_price.csv"
local_raw_file = "raw_housing.csv"

s3.download_file(bucket_name, key, local_raw_file)
print("Downloaded raw file from S3.")
# Out:
# Downloaded raw file from S3.

# %% [markdown]
# 3. Load Data into Pandas

# %%
df = pd.read_csv(local_raw_file)
print("Raw Shape:", df.shape)
df.head()
# Out:
# Raw Shape: (545, 3)
#    Unnamed: 0     price  area
# 0           0  13300000  7420
# 1           1  12250000  8960
# 2           2  12250000  9960
# 3           3  12215000  7500
# 4           4  11410000  7420

# %% [markdown]
# 4. Remove Duplicates

# %%
df = df.drop_duplicates().reset_index(drop=True)
print("After removing duplicates:", df.shape)
# Out:
# After removing duplicates: (545, 3)

# %% [markdown]
# 5. Outlier Removal (IQR Method)

# %%
def remove_outliers(df, cols):
    for col in cols:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        df = df[(df[col] >= lower) & (df[col] <= upper)]
    return df

numeric_cols = df.select_dtypes(include=["int64", "float64"]).columns
df = remove_outliers(df, numeric_cols)

print("Shape after outlier removal:", df.shape)
# Out:
# Shape after outlier removal: (517, 3)

# %% [markdown]
# 6. Encoding Categorical Columns

# %%
label_encoder = LabelEncoder()

for col in df.select_dtypes(include=["object"]).columns:
    df[col] = label_encoder.fit_transform(df[col])

# %% [markdown]
# 7. Feature Scaling

# %%
scaler = StandardScaler()
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

# %% [markdown]
# 8. Save Cleaned File Locally

# %%
cleaned_file = "cleaned_housing.csv"
df.to_csv(cleaned_file, index=False)
print("Saved cleaned dataset locally.")
# Out:
# Saved cleaned dataset locally.

# %% [markdown]
# 9. Upload Cleaned Dataset Back to S3

# %%
cleaned_key = "processed/cleaned_housing.csv"

s3.upload_file(cleaned_file, bucket_name, cleaned_key)
print("Uploaded cleaned dataset back to S3.")
# Out:
# Uploaded cleaned dataset back to S3.

# %% [markdown]
# 10. Start Athena Query

# %%
athena = boto3.client("athena")

query = """
SELECT * FROM house_price.housing_cleaned LIMIT 10;
"""

output_location = "s3://aws-practice-visualpath/"

# %%
response = athena.start_query_execution(
    QueryString=query,
    QueryExecutionContext={'Database': 'house_price'},
    ResultConfiguration={'OutputLocation': output_location}
)

query_id = response["QueryExecutionId"]
print("Query ID:", query_id)
# Out:
# Query ID: 608d59d5-ef4d-42fc-b566-3848ee50f3f9

# %% [markdown]
# 11. Poll Until Query Completes

# %%
import time

while True:
    status = athena.get_query_execution(QueryExecutionId=query_id)
    state = status["QueryExecution"]["Status"]["State"]

    if state in ["SUCCEEDED", "FAILED", "CANCELLED"]:
        break

    print("Query running...")
    time.sleep(2)

print("Final state:", state)
# Out:
# Final state: SUCCEEDED

# %% [markdown]
# 12. Get Query Results

# %%
if state == "SUCCEEDED":
    results = athena.get_query_results(QueryExecutionId=query_id)
    for row in results["ResultSet"]["Rows"]:
        print(row)
# Out:
# {'Data': [{'VarCharValue': 'price'}, {'VarCharValue': 'area'}, {'VarCharValue': 'bedrooms'}, {'VarCharValue': 'bathrooms'}, {'VarCharValue': 'stories'}, {'VarCharValue': 'mainroad'}, {'VarCharValue': 'guestroom'}, {'VarCharValue': 'basement'}, {'VarCharValue': 'hotwaterheating'}, {'VarCharValue': 'airconditioning'}, {'VarCharValue': 'parking'}, {'VarCharValue': 'prefarea'}, {'VarCharValue': 'furnishingstatus'}]}
# {'Data': [{'VarCharValue': ''}, {'VarCharValue': 'price'}, {'VarCharValue': 'area'}, {'VarCharValue': 'bedrooms'}, {'VarCharValue': 'bathrooms'}, {'VarCharValue': 'stories'}, {'VarCharValue': 'mainroad'}, {'VarCharValue': 'guestroom'}, {'VarCharValue': 'basement'}, {'VarCharValue': 'hotwaterheating'}, {'VarCharValue': 'airconditioning'}, {'VarCharValue': 'parking'}, {'VarCharValue': 'prefarea'}]}
# {'Data': [{'VarCharValue': '15'}, {'VarCharValue': '4.05869499602107'}, {'VarCharValue': '0.7994747830761767'}, {'VarCharValue': '2.017626274203175'}, {'VarCharValue': '0.0'}, {'VarCharValue': '0.7257285970598193'}, {'VarCharValue': '1'}, {'VarCharValue': '0'}, {'VarCharValue': '1'}, {'VarCharValue': '0'}, {'VarCharValue': '0'}, {'VarCharValue': '1.9253528290154525'}, {'VarCharValue': '0'}]}
# {'Data': [{'VarCharValue': '20'}, {'VarCharValue': '3.777676852951908'}, {'VarCharValue': '-0.17649406673999535'}, {'VarCharValue': '0.4131957947169902'}, {'VarCharValue': '0.0'}, {'VarCharValue': '0.7257285970598193'}, {'VarCharValue': '1'}, {'VarCharValue': '0'}, {'VarCharValue': '1'}, {'VarCharValue': '1'}, {'VarCharValue': '0'}, {'VarCharValue': '1.9253528290154525'}, {'VarCharValue': '0'}]}
# {'Data': [{'VarCharValue': '22'}, {'VarCharValue': '3.6933714100311588'}, {'VarCharValue': '1.990389153387577'}, {'VarCharValue': '0.4131957947169902'}, {'VarCharValue': '0.0'}, {'VarCharValue': '-0.899369181632414'}, {'VarCharValue': '1'}, {'VarCharValue': '1'}, {'VarCharValue': '1'}, {'VarCharValue': '0'}, {'VarCharValue': '1'}, {'VarCharValue': '0.6093345095573248'}, {'VarCharValue': '0'}]}
# {'Data': [{'VarCharValue': '27'}, {'VarCharValue': '3.496658709882745'}, {'VarCharValue': '2.4696595707080187'}, {'VarCharValue': '0.4131957947169902'}, {'VarCharValue': '0.0'}, {'VarCharValue': '-0.899369181632414'}, {'VarCharValue': '1'}, {'VarCharValue': '0'}, {'VarCharValue': '0'}, {'VarCharValue': '0'}, {'VarCharValue': '0'}, {'VarCharValue': '0.6093345095573248'}, {'VarCharValue': '0'}]}
# {'Data': [{'VarCharValue': '40'}, {'VarCharValue': '3.0751314952790003'}, {'VarCharValue': '1.1189883946231378'}, {'VarCharValue': '0.4131957947169902'}, {'VarCharValue': '0.0'}, {'VarCharValue': '0.7257285970598193'}, {'VarCharValue': '1'}, {'VarCharValue': '0'}, {'VarCharValue': '1'}, {'VarCharValue': '0'}, {'VarCharValue': '1'}, {'VarCharValue': '-0.7066838099008028'}, {'VarCharValue': '1'}]}
# {'Data': [{'VarCharValue': '55'}, {'VarCharValue': '2.6536042806752564'}, {'VarCharValue': '0.7994747830761767'}, {'VarCharValue': '0.4131957947169902'}, {'VarCharValue': '0.0'}, {'VarCharValue': '0.7257285970598193'}, {'VarCharValue': '1'}, {'VarCharValue': '0'}, {'VarCharValue': '0'}, {'VarCharValue': '0'}, {'VarCharValue': '1'}, {'VarCharValue': '0.6093345095573248'}, {'VarCharValue': '0'}]}
# {'Data': [{'VarCharValue': '61'}, {'VarCharValue': '2.428789766219926'}, {'VarCharValue': '2.4725642399039'}, {'VarCharValue': '-1.1912346847691948'}, {'VarCharValue': '0.0'}, {'VarCharValue': '-0.899369181632414'}, {'VarCharValue': '1'}, {'VarCharValue': '0'}, {'VarCharValue': '0'}, {'VarCharValue': '0'}, {'VarCharValue': '1'}, {'VarCharValue': '0.6093345095573248'}, {'VarCharValue': '0'}]}
# {'Data': [{'VarCharValue': '68'}, {'VarCharValue': '2.260178880378428'}, {'VarCharValue': '0.7994747830761767'}, {'VarCharValue': '0.4131957947169902'}, {'VarCharValue': '0.0'}, {'VarCharValue': '-0.899369181632414'}, {'VarCharValue': '1'}, {'VarCharValue': '0'}, {'VarCharValue': '0'}, {'VarCharValue': '0'}, {'VarCharValue': '1'}, {'VarCharValue': '0.6093345095573248'}, {'VarCharValue': '0'}]}
# {'Data': [{'VarCharValue': '74'}, {'VarCharValue': '2.0915679945369305'}, {'VarCharValue': '-0.33915554170935736'}, {'VarCharValue': '0.4131957947169902'}, {'VarCharValue': '0.0'}, {'VarCharValue': '0.7257285970598193'}, {'VarCharValue': '1'}, {'VarCharValue': '0'}, {'VarCharValue': '1'}, {'VarCharValue': '1'}, {'VarCharValue': '0'}, {'VarCharValue': '0.6093345095573248'}, {'VarCharValue': '0'}]}
