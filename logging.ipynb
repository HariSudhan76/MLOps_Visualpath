# %%
import logging

# %%
logger = logging.getLogger("my_mlops_proj")

# %%
def main():
    logging.basicConfig(level="INFO")
    logger.debug("Debug message")
    logger.info("Info message")
    logger.warning("warning message")
    logger.error("error message")
    logger.critical("")

# %%
print(1/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(1/0)
#
# ZeroDivisionError: division by zero

# %%
try:
    print(1/0)
except ZeroDivisionError:
    logger.exception("Please have the denominator value greater than 0")
# Out:
# Please have the denominator value greater than 0
# Traceback (most recent call last):
#   File "C:\Users\Boss Baby\AppData\Local\Temp\ipykernel_12900\149628750.py", line 2, in <module>
#     print(1/0)
#           ~^~
# ZeroDivisionError: division by zero
# None

# %%
if __name__=="__main__":
    main()
# Out:
# DEBUG:my_mlops_proj:Debug message
# INFO:my_mlops_proj:Info message
# WARNING:my_mlops_proj:warning message
# ERROR:my_mlops_proj:error message
# CRITICAL:my_mlops_proj:

# %%
log_path = "sample_data/train.log"

logging.basicConfig(filename=log_path, level=logging.INFO)
logging.
