# %%
import pickle

def add(a,b):
    return a+b

# %%
with open('model_pickle','wb') as file:
    pickle.dump(add,file)

# %%
with open('model_pickle','rb') as f:
    mod = pickle.load(f)

# %%
mod(70,60)
# Out:
# 130

# %%
import joblib

# %%
joblib.dump(add,'joblib_file.pkl')
# Out:
# ['joblib_file.pkl']

# %%
jb = joblib.load('joblib_file.pkl')

# %%
jb(40,30)
# Out:
# 70

# %%
import sys
!"{sys.executable}" -m pip install joblib

# %%
import joblib
