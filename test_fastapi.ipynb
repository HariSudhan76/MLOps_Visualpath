# %%
from fastapi_app import FastAPI

app = FastAPI()

# --- ADD THIS SECTION ---
@app.get("/")
def read_root():
    return {"message": "Hello World"}
# ------------------------

# (Your other routes might be here)
# Out:
# c:\Users\harry\anaconda3\Lib\site-packages\pydantic\_internal\_config.py:383: UserWarning: Valid config keys have changed in V2:
# * 'schema_extra' has been renamed to 'json_schema_extra'
#   warnings.warn(message, UserWarning)
