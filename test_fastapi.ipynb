# %%
import requests

# %%
url = "http://18.234.217.48:8000/predict"

# %%
payload = {
  "pclass": 1,
  "sex": "female",
  "age": 25,
  "sibsp": 1,
  "parch": 1,
  "fare": 1000,
  "embarked": "S"
}

r = requests.post(url, json=payload)
print(r.json())
# Out:
# {'prediction': 1, 'probability': 0.85}

# %%
url_health = "http://18.234.217.48:8000/health"

# %%
health = requests.get(url_health)
health.json()
# Out:
# {'status': 'ok'}
