# %% [markdown]
# ## PROJECT 1 — Loan Default Risk Prediction (Banking Domain) – Classification
#
# #### 📌 Problem Statement:
#
# A bank wants to predict whether a customer will default on a loan based on financial history, employment data, credit behavior, and demographic variables.
# Your task is to build a complete ML pipeline that predicts Loan_Default = Yes/No.
#
# ##### 📊 Dataset you can download it from Kaggle
#
# 📌 What you must do:
#
# ##### Data Cleaning:
#         Handle missing financial values
#         Convert employment_type (categorical) to numeric
#         Convert “Yes/No” default to 1/0
#         Treat outliers using IQR or Winsorization
#
# ##### Train-Test Split
#         80-20 Rule
#
# ##### Model Training:
#         Train any 4 models:
#
# ##### Evaluation:
#         Precision, Recall, F1
#         ROC-AUC
#         Confusion Matrix
#         Classification Report
#
# ##### Save Best Model
#         as loan_default_model.pkl
